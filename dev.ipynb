# %%
# %%bash
#
# python src/pazy_scraper.py \
#     --log logs/pazy_scraper.log \
#     --output data/pazy
# Out:
# 2025-03-04 10:28:41 - INFO - Starting PAZy database scraping
# 2025-03-04 10:28:41 - INFO - Fetching polymer links from https://pazy.eu/doku.php?id=start
# 2025-03-04 10:28:41 - INFO - Found 12 polymer types
# 2025-03-04 10:28:41 - INFO - Processing polymer: Polyethylene terephthalate (PET)
# 2025-03-04 10:31:13 - INFO - Found 151 enzyme entries for Polyethylene terephthalate (PET)
# 2025-03-04 10:31:15 - INFO - Processing polymer: Polyurethane (PUR)
# 2025-03-04 10:31:15 - INFO - Found 0 enzyme entries for Polyurethane (PUR)
# 2025-03-04 10:31:17 - INFO - Processing polymer: Polyethylene (PE)
# 2025-03-04 10:31:18 - INFO - Found 0 enzyme entries for Polyethylene (PE)
# 2025-03-04 10:31:20 - INFO - Processing polymer: Polyamide (PA)
# 2025-03-04 10:31:20 - INFO - Found 0 enzyme entries for Polyamide (PA)
# 2025-03-04 10:31:22 - INFO - Processing polymer: Polystyrene (PS)
# 2025-03-04 10:31:23 - WARNING - No table found on Polystyrene (PS) page.
# ...

# %%
# %%bash
#
# python src/cross_reference_with_plasticdb.py \
#     --plasticdb data/plasticdb/PlasticDB.fasta \
#     --pazy data/pazy/PAZy_sequences.fasta \
#     --output data/cross_references.tsv \
#     --noduplicates
# Out:
# Processing PlasticDB file: data/plasticdb/PlasticDB.fasta
# Completed processing 228 PlasticDB sequences in 0.01 seconds
# Number of unique sequence hashes: 212
# Removed 16 duplicate sequences
# Processing PAZy file: data/pazy/PAZy_sequences.fasta
# Completed processing 141 PAZy sequences in 0.00 seconds
# Found 80 matches
# 80 cross-references written to data/cross_references.tsv
